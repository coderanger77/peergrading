# %% [markdown]
# ## Important links
#
# * Markdown cheat sheet :http://nestacms.com/docs/creating-content/markdown-cheat-sheet

# %% [markdown]
# ## Doubts
# * Should we have su stored or should we sample them as required in case of current estimate of student params?

# %% [markdown]
# ## Libraries and functions

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt

def limit(x,min,max):
    if(x<min):
        return min
    if(x>max):
        return max
    return x

# %% [markdown]
# ## Initializations

# %%
student_count=100
minmarks=0
maxmarks=100
no_of_grades=10

## true parameters
mu_true=60
sigma_true=15
beta_true=10  #beta is actually 10. so when we use 1/beta , we are using 0.1 instead

## intial priors for all the students.[beta,eta,mu,gama]

initial_beta=1
initial_eta=1
initial_mu= 50
initial_gama = 0.03333333333

# %% [markdown]
# ## Generate True Data

# %%
#generate true values
df_true=pd.DataFrame(columns=['id','s','b','t'])

for u in range(0,student_count):   
    #s_u true scores for each grader 
    su=np.random.normal(mu_true,sigma_true,1)[0]
    su=limit(su,minmarks,maxmarks)
        
    #bias of each user ranges from 0-
    bu=np.random.normal(0,no_of_grades,1)[0]
    bu=limit(bu,-no_of_grades,no_of_grades)
    
    #t -> reliability
    tu=np.random.normal(su,beta_true,1)[0]
    
    df_true.loc[u]=[int(u),su,bu,tu]
    
df_true['id']=df_true['id'].astype('int')

print(df_true.describe())
#min value of s is only 24 
#df_true.dtypes
#df_true
# Out:
#                id           s           b           t
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000   62.935818    0.858372   63.612252
# std     29.011492   13.877896    7.425447   17.454104
# min      0.000000   30.045945  -10.000000   28.197469
# 25%     24.750000   52.572323   -5.585965   51.287396
# 50%     49.500000   62.392142    0.351862   63.444821
# 75%     74.250000   72.156980    8.753118   73.687773
# max     99.000000  100.000000   10.000000  115.080288

# %% [markdown]
# ## Initialize prior for s_u, b_v and t_v

# %%
#df_student_params contains s,b,t and parameters beta,eta,mu,gama, 

df_student_params=pd.DataFrame(columns=['id','s','b','t','beta','eta','mu','gama'])


for i in range(0,student_count):
    
    #sampling student's score
    su=np.random.normal(intial_mu,1/intial_gama,1)[0]
    su=limit(su,minmarks,maxmarks)
    
    #bias of each user ranges from 0-no_of_grades
    bu=np.random.normal(0,no_of_grades,1)[0]
    bu=limit(bu,-no_of_grades,no_of_grades)
    
    #sampling reliability
    tu=np.random.normal(su,intial_beta,1)[0]
    
    df_student_params.loc[i]=[i,su,bu,tu,initial_beta,initial_eta,initial_mu,initial_gama]

    
df_student_params['id']=df_student_params['id'].astype(int)
df_student_params
# Out:
#     id           s          b           t  beta  eta    mu      gama
# 0    0   47.226608  -0.893018   47.639968   1.0  1.0  50.0  0.033333
# 73  73   90.294186  -1.519422   90.451593   1.0  1.0  50.0  0.033333
# 74  74   28.277439   6.106877   27.443055   1.0  1.0  50.0  0.033333
# 75  75    0.000000  -4.530557    0.583399   1.0  1.0  50.0  0.033333
# 76  76   11.303448   2.048703   10.785813   1.0  1.0  50.0  0.033333
# 77  77   32.755047 -10.000000   32.099431   1.0  1.0  50.0  0.033333
# 78  78  100.000000 -10.000000  100.283213   1.0  1.0  50.0  0.033333
# 79  79   11.676471  -1.024471   11.632601   1.0  1.0  50.0  0.033333
# 80  80   82.647877   5.588080   80.916595   1.0  1.0  50.0  0.033333
# 81  81  100.000000   1.103089   98.910301   1.0  1.0  50.0  0.033333
# 82  82    4.742851   3.026509    5.606363   1.0  1.0  50.0  0.033333
# 83  83   45.570763  10.000000   44.961588   1.0  1.0  50.0  0.033333
# 84  84   40.461101   1.209499   39.094093   1.0  1.0  50.0  0.033333
# 85  85   29.225999  -9.101774   28.276938   1.0  1.0  50.0  0.033333
# 86  86   66.793204  10.000000   67.730606   1.0  1.0  50.0  0.033333
# 87  87   69.866853  -1.421863   69.997188   1.0  1.0  50.0  0.033333
# 88  88   35.731000   6.457751   34.465844   1.0  1.0  50.0  0.033333
# 89  89   50.954645  -4.883824   50.216439   1.0  1.0  50.0  0.033333
# 90  90   94.175131 -10.000000   93.611727   1.0  1.0  50.0  0.033333
# 91  91   81.604036   5.624715   81.740399   1.0  1.0  50.0  0.033333
# 92  92    0.000000  10.000000   -0.105205   1.0  1.0  50.0  0.033333
# 93  93   18.925785  10.000000   20.438776   1.0  1.0  50.0  0.033333
# 94  94    6.559324  -0.086583    9.250784   1.0  1.0  50.0  0.033333
# 95  95   56.607696   8.412480   55.841357   1.0  1.0  50.0  0.033333
# 96  96   28.570560  10.000000   27.705843   1.0  1.0  50.0  0.033333
# 97  97   18.750288   1.607844   17.212381   1.0  1.0  50.0  0.033333
# 98  98   73.742680   7.306105   72.952403   1.0  1.0  50.0  0.033333
# 99  99   45.519390   8.973779   44.932115   1.0  1.0  50.0  0.033333
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Allocation algorithm
#
# * for each v in decreasing order of t
#     * for each u in U
#         * calculate IG and chose that (u,v) which gives max IG
#     * A U {(u,v)}

# %%
df_student_params.sort_values(by='t',ascending=False,inplace=True)

# IG function is yet to be completed.
def IG(u,v):
    return v-u
def allocate(df_student_params):
    A={}
    for v in df_student_params['id']:
        x=-10000
        v_u=-1
        for u in df_student_params['id']:
           if not(u in A.values()) and IG(u,v)>x:
            x=IG(u,v)
            v_u=u
        A[v]=v_u
    return A

# %% [markdown]
# ## Simulation of actual Z
